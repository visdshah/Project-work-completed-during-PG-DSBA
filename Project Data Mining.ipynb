# %% [markdown]
# Spending	Amount spent by the customer per month (in 1000s)
# Advance_payments	Amount paid by the customer in advance by cash (in 100s)
# Probability_of_full_payment	Probability of payment done in full by the customer to the bank
# Current_balance	Balance amount left in the account to make purchases (in 1000s)
# Credit_limit	Limit of the amount in credit card (10000s)
# Min._payment_amt	minimum paid by the customer while making payments for purchases made monthly (in 100s)
# Max. spent_in_single_shopping	Maximum amount spent in one purchase (in 1000s)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #1.1 Read the data and do exploratory data analysis

# %%
df1 = pd.read_csv("C:\\Users\\user\\Desktop\\PG-DSBA\\Python for Data Science\\Data Mining Week 4\\Project 4\\bank_marketing_part1_Data.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   spending                      210 non-null    float64
#  1   advance_payments              210 non-null    float64
#  2   probability_of_full_payment   210 non-null    float64
#  3   current_balance               210 non-null    float64
#  4   credit_limit                  210 non-null    float64
#  5   min_payment_amt               210 non-null    float64
#  6   max_spent_in_single_shopping  210 non-null    float64
# dtypes: float64(7)
# memory usage: 11.6 KB

# %%
df1.isna().sum()
# Out:
# spending                        0
# advance_payments                0
# probability_of_full_payment     0
# current_balance                 0
# credit_limit                    0
# min_payment_amt                 0
# max_spent_in_single_shopping    0
# dtype: int64

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [spending, advance_payments, probability_of_full_payment, current_balance, credit_limit, min_payment_amt, max_spent_in_single_shopping]
# Index: []

# %%
# #  It is to bring all values of data to its complete units.
# df['spending'] = df['spending']*1000
# df['advance_payments'] = df['advance_payments']*100
# df['current_balance'] = df['current_balance']*1000
# df['credit_limit'] = df['credit_limit']*10000
# df['min_payment_amt'] = df['min_payment_amt']*100
# df['max_spent_in_single_shopping'] = df['max_spent_in_single_shopping']*1000

# %%
# # Creating Box and Hist plot
# n = 1
# plt.figure(figsize = (13,13))

# for i in df.columns:
#     plt.subplot(7,2,n)
#     plt.tight_layout()
#     sns.boxplot(df[i])
#     n = n+1
    
#     plt.subplot(7,2,n)
#     plt.tight_layout()
#     sns.histplot(df[i], kde= True)
#     n = n +1

# %%
df1.describe().round(2)
# Out:
#        spending  advance_payments  probability_of_full_payment  \
# count    210.00            210.00                       210.00
# mean      14.85             14.56                         0.87
# std        2.91              1.31                         0.02
# min       10.59             12.41                         0.81
# 25%       12.27             13.45                         0.86
# 50%       14.36             14.32                         0.87
# 75%       17.30             15.72                         0.89
# max       21.18             17.25                         0.92
#
#        current_balance  credit_limit  min_payment_amt  \
# count           210.00        210.00           210.00
# mean              5.63          3.26             3.70
# std               0.44          0.38             1.50
# min               4.90          2.63             0.77
# 25%               5.26          2.94             2.56
# 50%               5.52          3.24             3.60
# ...

# %%
df1.head()
# Out:
#    spending  advance_payments  probability_of_full_payment  current_balance  \
# 0     19.94             16.92                       0.8752            6.675
# 1     15.99             14.89                       0.9064            5.363
# 2     18.95             16.42                       0.8829            6.248
# 3     10.83             12.96                       0.8099            5.278
# 4     17.99             15.86                       0.8992            5.890
#
#    credit_limit  min_payment_amt  max_spent_in_single_shopping
# 0         3.763            3.252                         6.550
# 1         3.582            3.336                         5.144
# 2         3.755            3.368                         6.148
# 3         2.641            5.182                         5.185
# 4         3.694            2.068                         5.837

# %%
from sklearn.preprocessing import StandardScaler
 
scaled_df_z = StandardScaler().fit_transform(df1)

# %%
scaled_df_z = pd.DataFrame(scaled_df_z,columns= df1.columns)
scaled_df_z.describe().round(2)
# Out:
#        spending  advance_payments  probability_of_full_payment  \
# count    210.00            210.00                       210.00
# mean       0.00              0.00                         0.00
# std        1.00              1.00                         1.00
# min       -1.47             -1.65                        -2.67
# 25%       -0.89             -0.85                        -0.60
# 50%       -0.17             -0.18                         0.10
# 75%        0.85              0.89                         0.71
# max        2.18              2.07                         2.01
#
#        current_balance  credit_limit  min_payment_amt  \
# count           210.00        210.00           210.00
# mean             -0.00         -0.00             0.00
# std               1.00          1.00             1.00
# min              -1.65         -1.67            -1.96
# 25%              -0.83         -0.83            -0.76
# 50%              -0.24         -0.06            -0.07
# ...

# %%
n = 1
plt.figure(figsize = (13,13))

for i in df1.columns:
    plt.subplot(7,2,n)
    plt.tight_layout()
    sns.boxplot(df1[i])
    n = n+1
    
    plt.subplot(7,2,n)
    plt.tight_layout()
    sns.boxplot(scaled_df_z[i])
    n = n +1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# 1.2 Justify scaling as necessary for clustering in this case and commenting about the difference in scale of different features on the bases of appropriate measure for example std dev, variance, etc. Justifying whether it’s is a necessity for scaling and method used to do the scaling. With explanation of working method.

# %%
from sklearn.preprocessing import minmax_scale

scaled_min_max = minmax_scale(df1)

scaled_min_max = pd.DataFrame(scaled_min_max,columns= df1.columns)

# %%
scaled_min_max.describe().round(2)
# Out:
#        spending  advance_payments  probability_of_full_payment  \
# count    210.00            210.00                       210.00
# mean       0.40              0.44                         0.57
# std        0.27              0.27                         0.21
# min        0.00              0.00                         0.00
# 25%        0.16              0.21                         0.44
# 50%        0.36              0.39                         0.59
# 75%        0.63              0.68                         0.72
# max        1.00              1.00                         1.00
#
#        current_balance  credit_limit  min_payment_amt  \
# count           210.00        210.00           210.00
# mean              0.41          0.45             0.38
# std               0.25          0.27             0.20
# min               0.00          0.00             0.00
# 25%               0.20          0.22             0.23
# 50%               0.35          0.43             0.37
# ...

# %%
n = 1
plt.figure(figsize = (13,13))

for i in df1.columns:
    plt.subplot(7,2,n)
    plt.tight_layout()
    sns.boxplot(df1[i])
    n = n+1
    
    plt.subplot(7,2,n)
    plt.tight_layout()
    sns.boxplot(scaled_min_max[i])
    n = n +1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
scaled_df = pd.DataFrame(scaled_min_max, columns= df1.columns)
plt.figure(figsize = (7,7))
sns.heatmap(scaled_min_max.corr().round(1), cmap = 'Spectral', annot= True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# <!--  -->Applying F-Clustering

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.cluster.hierarchy import fcluster

# %%
labelList = np.arange(1,210,1)

# %%
link = linkage(scaled_min_max,method = 'ward' )

# %%
#  Cutting the Dendrogram
dend = dendrogram(link,
    p=15,
    truncate_mode= 'lastp',
)

# %%
dend
# Out:
# {'icoord': [[25.0, 25.0, 35.0, 35.0],
#   [15.0, 15.0, 30.0, 30.0],
#   [5.0, 5.0, 22.5, 22.5],
#   [45.0, 45.0, 55.0, 55.0],
#   [65.0, 65.0, 75.0, 75.0],
#   [50.0, 50.0, 70.0, 70.0],
#   [95.0, 95.0, 105.0, 105.0],
#   [85.0, 85.0, 100.0, 100.0],
#   [135.0, 135.0, 145.0, 145.0],
#   [125.0, 125.0, 140.0, 140.0],
#   [115.0, 115.0, 132.5, 132.5],
#   [92.5, 92.5, 123.75, 123.75],
#   [60.0, 60.0, 108.125, 108.125],
#   [13.75, 13.75, 84.0625, 84.0625]],
#  'dcoord': [[0.0, 1.1641305603044698, 1.1641305603044698, 0.0],
#   [0.0, 1.777187059336429, 1.777187059336429, 1.1641305603044698],
#   [0.0, 2.319053953975703, 2.319053953975703, 1.777187059336429],
#   [0.0, 0.896608667337113, 0.896608667337113, 0.0],
#   [0.0, 1.357358664133796, 1.357358664133796, 0.0],
#   [0.896608667337113,
#    1.4060745762263795,
#    1.4060745762263795,
#    1.357358664133796],
#   [0.0, 1.3193588608471896, 1.3193588608471896, 0.0],
#   [0.0, 1.4447487145801376, 1.4447487145801376, 1.3193588608471896],
# ...

# %%
clusters = fcluster(link,4,criterion='maxclust')
clusters
# Out:
# array([1, 2, 1, 3, 1, 4, 3, 4, 1, 3, 1, 2, 3, 1, 4, 4, 2, 3, 4, 3, 4, 3,
#        1, 3, 2, 1, 4, 3, 3, 3, 4, 3, 3, 2, 3, 3, 3, 3, 3, 1, 1, 2, 1, 1,
#        3, 3, 4, 1, 1, 1, 3, 1, 1, 1, 1, 1, 3, 3, 3, 1, 2, 3, 3, 2, 2, 1,
#        1, 2, 1, 4, 2, 4, 1, 1, 3, 1, 2, 3, 1, 2, 2, 4, 2, 1, 3, 2, 2, 1,
#        1, 4, 4, 1, 2, 3, 4, 1, 1, 1, 3, 1, 4, 1, 2, 1, 2, 1, 1, 3, 4, 1,
#        2, 2, 1, 3, 3, 1, 2, 4, 3, 1, 4, 3, 3, 3, 2, 2, 1, 3, 2, 2, 3, 2,
#        4, 1, 3, 1, 1, 3, 1, 2, 4, 2, 3, 3, 4, 3, 1, 3, 2, 3, 2, 4, 2, 2,
#        4, 2, 4, 3, 2, 1, 1, 4, 1, 1, 1, 3, 1, 2, 4, 3, 2, 3, 2, 1, 1, 1,
#        2, 4, 2, 3, 2, 4, 4, 2, 2, 1, 4, 2, 4, 3, 4, 2, 3, 1, 2, 1, 1, 3,
#        1, 3, 2, 1, 2, 3, 1, 2, 1, 2, 2, 2], dtype=int32)

# %%
clustered_df = df1
clustered_df['clusters'] = pd.DataFrame(clusters)

# %%
clustered_df
# Out:
#      spending  advance_payments  probability_of_full_payment  current_balance  \
# 0       19.94             16.92                       0.8752            6.675
# 1       15.99             14.89                       0.9064            5.363
# 2       18.95             16.42                       0.8829            6.248
# 3       10.83             12.96                       0.8099            5.278
# 4       17.99             15.86                       0.8992            5.890
# ..        ...               ...                          ...              ...
# 205     13.89             14.02                       0.8880            5.439
# 206     16.77             15.62                       0.8638            5.927
# 207     14.03             14.16                       0.8796            5.438
# 208     16.12             15.00                       0.9000            5.709
# 209     15.57             15.15                       0.8527            5.920
#
# ...

# %%
n = 1
plt.figure(figsize = (12,12))
for i in clustered_df.columns:
    plt.subplot(4,2,n)
    sns.scatterplot(x = 'clusters',y = clustered_df[i],data = clustered_df,hue = 'clusters', palette= 'viridis',legend= False)
    n = n + 1
    plt.tight_layout()
    plt.xticks(np.arange(1,5,1))

# %%
sns.clustermap(clustered_df,cmap = 'Oranges_r')

# %% [markdown]
# 1.4 Applying K-Means clustering on scaled data and determine optimum clusters. Applying elbow curve and silhouette score. Interpreting the inferences from the model.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
# ploting inertia values to visualize optimal k value

wss = []

# %%
for i in range(1,9,1):
    KM  = KMeans(n_clusters= i,random_state= None)
    KM.fit(scaled_min_max)
    wss.append(KM.inertia_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
wss
# Out:
# [88.98592483911843,
#  34.81326792694562,
#  22.02436307566604,
#  18.66357409949538,
#  16.185186785808853,
#  14.594135787859603,
#  13.069773094332861,
#  11.925046068139043]

# %%
plt.plot(range(1,9,1),wss,marker='o', linestyle='dashed',color='orange')
plt.xlabel('Number of Clusters')
# Out:
# Text(0.5, 0, 'Number of Clusters')

# %%
wss_df = pd.DataFrame(wss, columns= {'Within sum of squares'})
wss_df['Clusters'] = np.arange(1,9,1)

# %%
wss_df
# Out:
#    Within sum of squares  Clusters
# 0              88.985925         1
# 1              34.813268         2
# 2              22.024363         3
# 3              18.663574         4
# 4              16.185187         5
# 5              14.594136         6
# 6              13.069773         7
# 7              11.925046         8

# %%
KM  = KMeans(n_clusters= 3)
KM.fit(scaled_min_max)
# Out:
# KMeans(n_clusters=3)

# %%
labels = KM.labels_
labels
# Out:
# array([0, 1, 0, 2, 0, 2, 2, 1, 0, 2, 0, 1, 2, 0, 2, 2, 1, 2, 2, 2, 2, 2,
#        0, 2, 1, 1, 1, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 0, 0, 1, 0, 0,
#        2, 2, 1, 0, 0, 0, 2, 0, 0, 0, 0, 0, 2, 2, 2, 0, 1, 2, 2, 1, 1, 0,
#        0, 1, 0, 2, 1, 2, 0, 0, 2, 0, 1, 2, 0, 1, 1, 1, 1, 0, 2, 1, 0, 1,
#        1, 2, 1, 0, 1, 2, 2, 0, 0, 0, 2, 0, 1, 0, 1, 0, 1, 0, 0, 2, 2, 0,
#        1, 1, 0, 2, 2, 0, 1, 1, 2, 0, 2, 2, 2, 2, 1, 1, 0, 2, 1, 1, 2, 1,
#        2, 0, 2, 0, 0, 2, 0, 1, 1, 1, 2, 2, 2, 2, 0, 2, 1, 2, 1, 2, 1, 1,
#        2, 1, 2, 2, 1, 0, 0, 2, 0, 0, 0, 2, 1, 1, 1, 2, 1, 2, 1, 0, 0, 0,
#        1, 2, 1, 2, 1, 1, 1, 1, 0, 0, 2, 1, 1, 2, 2, 1, 2, 0, 1, 0, 0, 2,
#        0, 2, 1, 0, 1, 2, 1, 1, 0, 1, 1, 1])

# %%
# removing clusters from decision tree model and adding up k means cluster numbers.
df1['KMeans_cluster'] = labels
df1 = df1.drop('clusters',axis =1)

# %%
df1
# Out:
#      spending  advance_payments  probability_of_full_payment  current_balance  \
# 0       19.94             16.92                       0.8752            6.675
# 1       15.99             14.89                       0.9064            5.363
# 2       18.95             16.42                       0.8829            6.248
# 3       10.83             12.96                       0.8099            5.278
# 4       17.99             15.86                       0.8992            5.890
# ..        ...               ...                          ...              ...
# 205     13.89             14.02                       0.8880            5.439
# 206     16.77             15.62                       0.8638            5.927
# 207     14.03             14.16                       0.8796            5.438
# 208     16.12             15.00                       0.9000            5.709
# 209     15.57             15.15                       0.8527            5.920
#
# ...

# %%
n = 1
plt.figure(figsize = (12,12))
for i in df1.columns:
    plt.subplot(3,3,n)
    sns.scatterplot(x = 'KMeans_cluster',y = df1[i],hue = 'KMeans_cluster',data = df1, palette= 'viridis',legend=False)
    n = n + 1
    plt.tight_layout()
    plt.xticks(np.arange(1,3,1))

# %%
silhouette_score(scaled_min_max, labels)
# Out:
# 0.42210525681247923

# %%
sil_width = silhouette_samples(scaled_min_max,labels)
df1['sil_width'] = sil_width

# %%
df1['sil_width'].max()
# Out:
# 0.6656353242228931

# %%
sns.scatterplot('sil_width', 'KMeans_cluster',hue= 'KMeans_cluster', palette= 'Set2' ,data = df1, legend= False)
# plt.yticks([0,1,2,3,4])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sil_width', ylabel='KMeans_cluster'>

# %%
# Cluster 1
df1[df1['KMeans_cluster'] == 0].describe().round(2)
# Out:
#        spending  advance_payments  probability_of_full_payment  \
# count     64.00             64.00                        64.00
# mean      18.61             16.25                         0.88
# std        1.18              0.51                         0.01
# min       16.16             15.18                         0.85
# 25%       17.89             15.88                         0.87
# 50%       18.78             16.26                         0.88
# 75%       19.16             16.60                         0.90
# max       21.18             17.25                         0.91
#
#        current_balance  credit_limit  min_payment_amt  \
# count            64.00         64.00            64.00
# mean              6.20          3.71             3.59
# std               0.22          0.16             1.22
# min               5.79          3.40             1.47
# 25%               6.04          3.57             2.84
# 50%               6.16          3.75             3.50
# ...

# %%
# Cluster 2
df1[df1['KMeans_cluster'] == 1].describe().round(2)
# Out:
#        spending  advance_payments  probability_of_full_payment  \
# count     69.00             69.00                        69.00
# mean      14.65             14.44                         0.88
# std        0.96              0.49                         0.02
# min       12.67             13.32                         0.85
# 25%       14.01             14.10                         0.87
# 50%       14.59             14.43                         0.88
# 75%       15.38             14.84                         0.89
# max       16.44             15.38                         0.92
#
#        current_balance  credit_limit  min_payment_amt  \
# count            69.00         69.00            69.00
# mean              5.55          3.29             2.80
# std               0.21          0.14             1.23
# min               4.98          2.98             0.77
# 25%               5.39          3.16             1.97
# 50%               5.57          3.29             2.70
# ...

# %%
# Cluster 3
df1[df1['KMeans_cluster'] == 2].describe().round(2)
# Out:
#        spending  advance_payments  probability_of_full_payment  \
# count     77.00             77.00                        77.00
# mean      11.90             13.26                         0.85
# std        0.71              0.35                         0.02
# min       10.59             12.41                         0.81
# 25%       11.27             13.00                         0.84
# 50%       11.87             13.23                         0.85
# 75%       12.44             13.52                         0.86
# max       13.34             13.95                         0.89
#
#        current_balance  credit_limit  min_payment_amt  \
# count            77.00         77.00            77.00
# mean              5.23          2.86             4.60
# std               0.14          0.14             1.43
# min               4.90          2.63             1.42
# 25%               5.14          2.76             3.63
# 50%               5.22          2.84             4.70
# ...

# %%
# df1.drop('sil_width','KMeans_cluster',axis =1,inplace = True)

# %%
plt.figure(figsize= (8,8))
sns.heatmap(df1.corr().round(1), cmap= 'cubehelix', annot= True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,10))

# %%
# df1['spending/credit_limit'] = df1['spending']/df1['credit_limit']
# df1['spending/max_spent_in_single_shopping'] = df1['spending']/df1['max_spent_in_single_shopping']
# df1['spending / min pay amnt ratio'] = df1['spending'] / df1['min_payment_amt']
# df1['max_spent_in_single_shopping/credit_limit'] = df1['max_spent_in_single_shopping']/df1['credit_limit']
# df1['max_spent_in_single_shopping/spending'] = df1['max_spent_in_single_shopping']/df1['spending']
# df1['advance_payments/min_payment_amt'] = df1['advance_payments'] / df1['min_payment_amt']
df1['advance_payments/current_balance'] = df1['advance_payments'] / df1['current_balance']
df1
# Out:
#      spending  advance_payments  probability_of_full_payment  current_balance  \
# 0       19.94             16.92                       0.8752            6.675
# 1       15.99             14.89                       0.9064            5.363
# 2       18.95             16.42                       0.8829            6.248
# 3       10.83             12.96                       0.8099            5.278
# 4       17.99             15.86                       0.8992            5.890
# ..        ...               ...                          ...              ...
# 205     13.89             14.02                       0.8880            5.439
# 206     16.77             15.62                       0.8638            5.927
# 207     14.03             14.16                       0.8796            5.438
# 208     16.12             15.00                       0.9000            5.709
# 209     15.57             15.15                       0.8527            5.920
#
# ...

# %%
df1['spending / min pay amnt ratio'] = df1['spending'] / df1['min_payment_amt']

# %%
plt.figure(figsize= (10,5))
sns.scatterplot('spending / min pay amnt ratio','probability_of_full_payment',hue = 'KMeans_cluster' ,data = df1)
plt.axvline(x=4, ymin=0, ymax=1, )
plt.axhline(y = 0.86)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize= (10,5))
sns.scatterplot('min_payment_amt','spending',hue = 'KMeans_cluster' ,data = df1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='min_payment_amt', ylabel='spending'>

# %%
plt.figure(figsize= (10,5))
sns.scatterplot('current_balance','spending',hue = 'KMeans_cluster' ,data = df1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='current_balance', ylabel='spending'>

# %%
plt.figure(figsize= (10,5))
sns.scatterplot('advance_payments/current_balance','spending',hue = 'KMeans_cluster' ,data = df1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='advance_payments/current_balance', ylabel='spending'>

# %%
plt.figure(figsize= (10,5))
sns.scatterplot('spending','credit_limit',hue = 'KMeans_cluster' ,data = df1)
plt.axvline(x= 13, ymin=0, ymax=3.2 )
plt.axhline(y = 3)
plt.axvline(x= 20, ymin=0, ymax=4 )
plt.axhline(y = 3.8)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## PROBLEM 2

# %% [markdown]
# 1. Claim Status (Claimed): Target
# 2. Code of tour firm (Agency_Code)
# 3. Type of tour insurance firms (Type)
# 4. Distribution channel of tour insurance agencies (Channel)
# 5. Name of the tour insurance products (Product)
# 6. Duration of the tour (Duration in days)
# 7. Destination of the tour (Destination)
# 8. Amount worth of (Sales) per customer in procuring tour insurance policies in rupees (in 100’s)
# 9. The commission received for tour insurance firm (Commission is in percentage of sales)
# 10.Age of insured (Age)

# %%
df = pd.read_csv('C:\\Users\\user\\Desktop\\PG-DSBA\\Python for Data Science\\Data Mining Week 4\\Project 4\\insurance_part2_data.csv')

# %%
df
# Out:
#       Age Agency_Code           Type Claimed  Commision Channel  Duration  \
# 0      48         C2B       Airlines      No       0.70  Online         7
# 1      36         EPX  Travel Agency      No       0.00  Online        34
# 2      39         CWT  Travel Agency      No       5.94  Online         3
# 3      36         EPX  Travel Agency      No       0.00  Online         4
# 4      33         JZI       Airlines      No       6.30  Online        53
# ...   ...         ...            ...     ...        ...     ...       ...
# 2995   28         CWT  Travel Agency     Yes     166.53  Online       364
# 2996   35         C2B       Airlines      No      13.50  Online         5
# 2997   36         EPX  Travel Agency      No       0.00  Online        54
# 2998   34         C2B       Airlines     Yes       7.64  Online        39
# 2999   47         JZI       Airlines      No      11.55  Online        15
#
#        Sales       Product Name Destination
# ...

# %%
df.isna().sum()
# Out:
# Age             0
# Agency_Code     0
# Type            0
# Claimed         0
# Commision       0
# Channel         0
# Duration        0
# Sales           0
# Product Name    0
# Destination     0
# dtype: int64

# %%
df2 = df.drop('Agency_Code',axis =1)
df2
# Out:
#       Age           Type Claimed  Commision Channel  Duration   Sales  \
# 0      48       Airlines      No       0.70  Online         7    2.51
# 1      36  Travel Agency      No       0.00  Online        34   20.00
# 2      39  Travel Agency      No       5.94  Online         3    9.90
# 3      36  Travel Agency      No       0.00  Online         4   26.00
# 4      33       Airlines      No       6.30  Online        53   18.00
# ...   ...            ...     ...        ...     ...       ...     ...
# 2995   28  Travel Agency     Yes     166.53  Online       364  256.20
# 2996   35       Airlines      No      13.50  Online         5   54.00
# 2997   36  Travel Agency      No       0.00  Online        54   28.00
# 2998   34       Airlines     Yes       7.64  Online        39   30.55
# 2999   47       Airlines      No      11.55  Online        15   33.00
#
#            Product Name Destination
# 0       Customised Plan        ASIA
# 1       Customised Plan        ASIA
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           3000 non-null   int64
#  1   Type          3000 non-null   object
#  2   Claimed       3000 non-null   object
#  3   Commision     3000 non-null   float64
#  4   Channel       3000 non-null   object
#  5   Duration      3000 non-null   int64
#  6   Sales         3000 non-null   float64
#  7   Product Name  3000 non-null   object
#  8   Destination   3000 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 211.1+ KB

# %%
df2.head()
# Out:
#    Age           Type Claimed  Commision Channel  Duration  Sales  \
# 0   48       Airlines      No       0.70  Online         7   2.51
# 1   36  Travel Agency      No       0.00  Online        34  20.00
# 2   39  Travel Agency      No       5.94  Online         3   9.90
# 3   36  Travel Agency      No       0.00  Online         4  26.00
# 4   33       Airlines      No       6.30  Online        53  18.00
#
#         Product Name Destination
# 0    Customised Plan        ASIA
# 1    Customised Plan        ASIA
# 2    Customised Plan    Americas
# 3  Cancellation Plan        ASIA
# 4        Bronze Plan        ASIA

# %%
n =1 
list_cont = df[['Age','Commision','Sales','Duration']]
plt.figure(figsize = (10,7))
for features in list_cont.columns:
    plt.subplot(2,2,n)
    sns.barplot(x = df2.Claimed, y = list_cont[features] , data = df2 , ci = False)
    n = n + 1
    plt.tight_layout()

# %%
n =1 
list_cat = df[['Type','Claimed','Channel','Product Name','Destination']]
plt.figure(figsize = (6,10))
for features in list_cat.columns:
    a = pd.crosstab(index = df2.Claimed, columns = list_cat[features])
    a.plot.bar(stacked=True)

# %%
# pd.crosstab(index= df2.Claimed, columns= df['Type'],normalize= True).round(2)
pd.crosstab(index= df2.Claimed, columns= df['Type'],margins= 'All')
# Out:
# Type     Airlines  Travel Agency   All
# Claimed
# No            573           1503  2076
# Yes           590            334   924
# All          1163           1837  3000

# %%
pd.crosstab(index= df2.Claimed, columns= df['Claimed'],normalize= True).round(2)
# pd.crosstab(index= df2.Claimed, columns= df['Claimed'],margins= 'All')
# Out:
# Claimed    No   Yes
# Claimed
# No       0.69  0.00
# Yes      0.00  0.31

# %%
# pd.crosstab(index= df2.Claimed, columns= df['Channel'],normalize= True).round(2)
pd.crosstab(index= df2.Claimed, columns= df['Channel'],margins= 'All')
# Out:
# Channel  Offline  Online   All
# Claimed
# No            29    2047  2076
# Yes           17     907   924
# All           46    2954  3000

# %%
# pd.crosstab(index= df2.Claimed, columns= df['Product Name'],normalize= True).round(2)
pd.crosstab(index= df2.Claimed, columns= df['Product Name'],margins = 'All')
# Out:
# Product Name  Bronze Plan  Cancellation Plan  Customised Plan  Gold Plan  \
# Claimed
# No                    399                635              882         39
# Yes                   251                 43              254         70
# All                   650                678             1136        109
#
# Product Name  Silver Plan   All
# Claimed
# No                    121  2076
# Yes                   306   924
# All                   427  3000

# %%
# pd.crosstab(index= df2.Claimed, columns= df['Destination'],normalize= True).round(2)
pd.crosstab(index= df2.Claimed, columns= df['Destination'],margins= 'All')
# Out:
# Destination  ASIA  Americas  EUROPE   All
# Claimed
# No           1691       232     153  2076
# Yes           774        88      62   924
# All          2465       320     215  3000

# %%
claimed_product = df2[df2['Claimed'] == 1].groupby('Product Name').sum()
claimed_product['claims %'] = claimed_product.Claimed*100/ claimed_product.Claimed.sum()
claimed_product['Sales/Claim'] = claimed_product.Sales/ claimed_product.Claimed.sum()
claimed_product['Commision/Claim'] = claimed_product.Commision/ claimed_product.Claimed.sum()
claimed_product
# Out:
#                 Age   Type  Claimed  Commision  Channel  Duration     Sales  \
# Product Name
# 0              9235    5.0    251.0    2954.84    251.0      8882  11515.42
# 1              1505   43.0     43.0       0.00     43.0      2715   1542.00
# 2              9477  247.0    254.0    3846.87    238.0     14533  15913.53
# 3              2910   31.0     70.0    4891.32     69.0     13796  13414.50
# 4             11634    8.0    306.0   12229.45    306.0     64652  47458.05
#
#               Destination   claims %  Sales/Claim  Commision/Claim
# Product Name
# 0                    10.0  27.164502    12.462576         3.197879
# 1                    19.0   4.653680     1.668831         0.000000
# 2                   161.0  27.489177    17.222435         4.163279
# 3                    17.0   7.575758    14.517857         5.293636
# 4                     5.0  33.116883    51.361526        13.235335

# %%
df2.groupby('Type').sum()
# Out:
#         Age  Claimed  Commision  Channel  Duration     Sales  Product Name  \
# Type
# 0     45049    590.0   24963.35   1163.0    120244  96416.67        1948.0
# 1     69224    334.0   18624.26   1791.0     89760  84333.07        3037.0
#
#       Destination
# Type
# 0            24.0
# 1           726.0

# %%
# One hot encoding
# df_new = pd.get_dummies(df,drop_first = True,columns= ['Agency_Code','Type','Claimed','Channel','Product Name','Destination'])
# df_new

# %%
# Modifying features to categorical codes.
for features in df2.columns:
    if df2[features].dtype == 'object':
        print(df2[features].value_counts())
        df2[features] = pd.Categorical(df2[features]).codes

# %%
df2[df2.duplicated()]
# Out:
#       Age  Type  Claimed  Commision  Channel  Duration  Sales  Product Name  \
# 63     30     0        1       15.0        1        27   60.0             0
# 329    36     1        0        0.0        1         5   20.0             2
# 407    36     1        0        0.0        1        11   19.0             1
# 411    35     1        0        0.0        1         2   20.0             2
# 422    36     1        0        0.0        1         5   20.0             2
# ...   ...   ...      ...        ...      ...       ...    ...           ...
# 2940   36     1        0        0.0        1         8   10.0             1
# 2947   36     1        0        0.0        1        10   28.0             2
# 2952   36     1        0        0.0        1         2   10.0             1
# 2962   36     1        0        0.0        1         4   20.0             2
# 2984   36     1        0        0.0        1         1   20.0             2
#
#       Destination
# 63              0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           3000 non-null   int64
#  1   Type          3000 non-null   int8
#  2   Claimed       3000 non-null   int8
#  3   Commision     3000 non-null   float64
#  4   Channel       3000 non-null   int8
#  5   Duration      3000 non-null   int64
#  6   Sales         3000 non-null   float64
#  7   Product Name  3000 non-null   int8
#  8   Destination   3000 non-null   int8
# dtypes: float64(2), int64(2), int8(5)
# memory usage: 108.5 KB

# %%
n = 1
list_cont = df[['Age','Commision','Sales','Duration']]
plt.figure(figsize = (13,7))
for features in list_cont.columns:
    plt.subplot(2,2,n)
    sns.boxplot(list_cont[features])
    n = n + 1
    plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df2.describe(include = 'all')
# Out:
#                Age         Type      Claimed    Commision      Channel  \
# count  3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean     38.091000     0.612333     0.308000    14.529203     0.984667
# std      10.463518     0.487299     0.461744    25.481455     0.122895
# min       8.000000     0.000000     0.000000     0.000000     0.000000
# 25%      32.000000     0.000000     0.000000     0.000000     1.000000
# 50%      36.000000     1.000000     0.000000     4.630000     1.000000
# 75%      42.000000     1.000000     1.000000    17.235000     1.000000
# max      84.000000     1.000000     1.000000   210.210000     1.000000
#
#           Duration        Sales  Product Name  Destination
# count  3000.000000  3000.000000   3000.000000  3000.000000
# mean     70.001333    60.249913      1.661667     0.250000
# std     134.053313    70.733954      1.258726     0.575277
# min      -1.000000     0.000000      0.000000     0.000000
# ...

# %%
df2[(df2.Claimed == 'No')]['Duration'].mean()
# Out:
# nan

# %%
df2[(df2.Claimed == 'Yes')]['Duration'].mean()
# Out:
# nan

# %%
df2[(df2.Claimed == 'No')]['Sales'].sum()
# Out:
# 0.0

# %%
df2[(df2.Claimed == 'Yes')]['Commision'].value_counts()
# Out:
# Series([], Name: Commision, dtype: int64)

# %%
df2[(df2.Claimed == 'Yes')]['Duration'].value_counts()
# Out:
# Series([], Name: Duration, dtype: int64)

# %%
df2[(df2.Claimed == 'Yes')]['Age'].value_counts()
# Out:
# Series([], Name: Age, dtype: int64)

# %%
n = 1
list_cont = df[['Age','Commision','Sales','Duration']]
plt.figure(figsize = (13,7))
for features in list_cont.columns:
    plt.subplot(2,2,n)
    sns.histplot(list_cont[features], kde = True)
    n = n + 1
    plt.tight_layout()

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df2.corr().round(2), annot = True , cmap = 'Spectral')
# Out:
# <AxesSubplot:>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestClassifier

from sklearn.neural_network import MLPClassifier

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
from sklearn.model_selection import train_test_split
y = df2['Claimed']

x = df2.drop(['Claimed'],axis =1)

# %%
x_train,x_test,train_labels,test_labels = train_test_split(x,y,test_size=0.30,random_state=None,)

# %% [markdown]
# # Decision Tree

# %%
dt_model = DecisionTreeClassifier(criterion= 'gini',
                                  max_depth= 10, 
                                  min_samples_leaf= 30,
                                  min_samples_split= 90)
dt_model.fit(x_train,train_labels)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=30, min_samples_split=90)

# %%
train_char_label = ['No','Yes']

# %%
insurance_tree_file = open('insurance_tree_file.dot','w')

dot_data =tree.export_graphviz(dt_model, 
                    out_file= 'insurance_tree_file.dot',
                    feature_names= list(x_train),
                               filled = True,
                    class_names= train_char_label)

# %%
insurance_tree_file.close()

# %%
# Visualize on graphviz editor

# %%
#  Features as per their importance
pd.DataFrame(dt_model.feature_importances_.round(2), 
                   columns= ['Feature_Importance'], 
                   index = x_train.columns)
# Out:
#               Feature_Importance
# Age                         0.01
# Type                        0.00
# Commision                   0.07
# Channel                     0.00
# Duration                    0.06
# Sales                       0.20
# Product Name                0.67
# Destination                 0.00

# %%
# Predictions of outcomes

ytrain_predict1 = dt_model.predict(x_train)
ytest_predict1 = dt_model.predict(x_test)

# %%
# Probabilities of 0s and 1s outcome

ytrain_predict2 = dt_model.predict_proba(x_train)
ytest_predict2 = dt_model.predict_proba(x_test)

# %%
# performance measure

from sklearn.metrics import roc_auc_score,roc_curve

# %% [markdown]
# ### AUC and ROC for the training data

# %%
# keep probabilities for the positive outcome only
ytrain_predict2 = ytrain_predict2[:,1]
# calculate AUC

auc = roc_auc_score(train_labels, ytrain_predict2)
print('AUC: %.3f' % auc)

# calculate roc curve
fpr, tpr, thresholds = roc_curve(train_labels, ytrain_predict2)
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.839

# %% [markdown]
# ### AUC and ROC for the test data

# %%
# keep probabilities for the positive outcome only
ytest_predict2 = ytest_predict2[:, 1]

# calculate AUC
auc = roc_auc_score(test_labels, ytest_predict2)
print('AUC: %.3f' % auc)

# calculate roc curve
fpr, tpr, thresholds = roc_curve(test_labels, ytest_predict2)
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.794

# %% [markdown]
# ## Confusion Matrix for the training data

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
confusion_matrix(train_labels, ytrain_predict1)
# Out:
# array([[1282,  148],
#        [ 300,  370]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(train_labels, ytrain_predict1), annot = True, cmap = 'inferno_r', fmt='4g')
# Out:
# <AxesSubplot:>

# %%
#Train Data Accuracy
dt_model.score(x_train,train_labels)
# Out:
# 0.7866666666666666

# %%
print((1318+361 )/ (1318+361+160+261))
# Out:
# 0.7995238095238095

# %%
print(classification_report(train_labels, ytrain_predict1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85      1430
#            1       0.71      0.55      0.62       670
#
#     accuracy                           0.79      2100
#    macro avg       0.76      0.72      0.74      2100
# weighted avg       0.78      0.79      0.78      2100

# %% [markdown]
# ## Confusion Matrix for test data

# %%
confusion_matrix(test_labels, ytest_predict1)
# Out:
# array([[556,  90],
#        [133, 121]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(test_labels, ytest_predict1), annot = True, cmap = 'inferno_r', fmt='4g')
# Out:
# <AxesSubplot:>

# %%
#Test Data Accuracy
dt_model.score(x_test,test_labels)
# Out:
# 0.7522222222222222

# %%
print((520+159)/(520+159+78+143))
# Out:
# 0.7544444444444445

# %%
print(classification_report(test_labels, ytest_predict1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       646
#            1       0.57      0.48      0.52       254
#
#     accuracy                           0.75       900
#    macro avg       0.69      0.67      0.68       900
# weighted avg       0.74      0.75      0.74       900

# %% [markdown]
# # Random Forest

# %%
rfcl = RandomForestClassifier()

# %%
params = {
    'n_estimators':[100,300,500],
    'max_depth':[5,10],
    'min_samples_leaf':[5,15,20],
    'min_samples_split':[50,100],
    'bootstrap':['True'],
    'oob_score':['True'],
    'random_state':[1]
}

# %%
grid = GridSearchCV(estimator = rfcl,verbose=True,param_grid = params,cv=3)

# %%
model = grid.fit(x_train,train_labels)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits

# %%
model.best_params_
# Out:
# {'bootstrap': 'True',
#  'max_depth': 5,
#  'min_samples_leaf': 20,
#  'min_samples_split': 50,
#  'n_estimators': 100,
#  'oob_score': 'True',
#  'random_state': 1}

# %%
best_grid = model.best_estimator_

# %%
ytrain_predict = best_grid.predict(x_train)
ytest_predict = best_grid.predict(x_test)

# %%
ytrain_predict1 = best_grid.predict_proba(x_train)
ytest_predict1 = best_grid.predict_proba(x_test)

# %%
sns.heatmap(confusion_matrix(train_labels,ytrain_predict), annot = True, cmap = 'inferno_r', fmt='4g')
# Out:
# <AxesSubplot:>

# %%
(1320+387)/(1320+276+387+117)
# Out:
# 0.8128571428571428

# %%
best_grid.score(x_train,train_labels)
# Out:
# 0.7704761904761904

# %%
print(classification_report(train_labels, ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.93      0.85      1430
#            1       0.73      0.44      0.55       670
#
#     accuracy                           0.77      2100
#    macro avg       0.76      0.68      0.70      2100
# weighted avg       0.76      0.77      0.75      2100

# %%
# keep probabilities for the positive outcome only
ytrain_predict1 = ytrain_predict1[:,1]

# calculate roc curve
fpr, tpr, thresholds = roc_curve(train_labels, ytrain_predict1)
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(fpr, tpr, marker='x')

# show the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()

# calculate AUC
auc = roc_auc_score(train_labels, ytrain_predict1)
print('Area under Curve is AUC: %.2f' % auc)
# Out:
# Area under Curve is AUC: 0.83

# %%
#  Similarily for test data

# %%
sns.heatmap(confusion_matrix(test_labels,ytest_predict), annot = True, cmap = 'rainbow', fmt='4g')
# Out:
# <AxesSubplot:>

# %%
(550+133)/(550+133+128+89)
# Out:
# 0.7588888888888888

# %%
best_grid.score(x_test,test_labels)
# Out:
# 0.7755555555555556

# %%
print(classification_report(test_labels,ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.85       646
#            1       0.67      0.41      0.51       254
#
#     accuracy                           0.78       900
#    macro avg       0.73      0.66      0.68       900
# weighted avg       0.76      0.78      0.76       900

# %%
# keep probabilities for the positive outcome only
ytest_predict1 = ytest_predict1[:,1]

# calculate roc curve
fpr, tpr, thresholds = roc_curve(test_labels, ytest_predict1)
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(fpr, tpr, marker='x')

# show the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()

# calculate AUC
auc = roc_auc_score(test_labels, ytest_predict1)
print('Area under Curve is AUC: %.2f' % auc)
# Out:
# Area under Curve is AUC: 0.80

# %% [markdown]
# # ANN - MLP Classifier

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import classification_report,confusion_matrix

# %%
sc = StandardScaler()

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.3, random_state  =1)

# %%
x_train = sc.fit_transform(x_train)

# %%
x_test = sc.transform(x_test)

# %%
clf = MLPClassifier(hidden_layer_sizes= [100,200,300], max_iter= 5000, solver = 'sgd', verbose= True, random_state= 1, tol= 0.001)

# %%
clf.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 0.70701323
# Iteration 2, loss = 0.68983850
# Iteration 3, loss = 0.67096120
# Iteration 4, loss = 0.65475136
# Iteration 5, loss = 0.64174613
# Iteration 6, loss = 0.63049912
# Iteration 7, loss = 0.62119136
# Iteration 8, loss = 0.61275079
# Iteration 9, loss = 0.60508141
# Iteration 10, loss = 0.59814854
# Iteration 11, loss = 0.59165782
# Iteration 12, loss = 0.58562977
# Iteration 13, loss = 0.57998612
# Iteration 14, loss = 0.57459346
# Iteration 15, loss = 0.56960284
# Iteration 16, loss = 0.56481278
# Iteration 17, loss = 0.56030461
# Iteration 18, loss = 0.55595806
# Iteration 19, loss = 0.55186840
# Iteration 20, loss = 0.54807061
# Iteration 21, loss = 0.54436315
# Iteration 22, loss = 0.54091075
# Iteration 23, loss = 0.53768950
# Iteration 24, loss = 0.53464365
# Iteration 25, loss = 0.53165583
# Iteration 26, loss = 0.52896932
# Iteration 27, loss = 0.52646497
# Iteration 28, loss = 0.52400944
# Iteration 29, loss = 0.52181237
# ...

# %%
# Applying MLP classifier

# %%
parameters = {
    'hidden_layer_sizes': [300,400,500],
    'max_iter': [8000,9000],
    'solver': ['sgd','adam'],
    'tol': [0.001,0.0001],
#     'activation':['relu','tanh','logistic','identity']
}

model = MLPClassifier(random_state=1)

grid_search = GridSearchCV(estimator = model, param_grid = parameters, cv = 3)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=MLPClassifier(random_state=1),
#              param_grid={'hidden_layer_sizes': [300, 400, 500],
#                          'max_iter': [8000, 9000], 'solver': ['sgd', 'adam'],
#                          'tol': [0.001, 0.0001]})

# %%
grid_search.best_params_
# Out:
# {'hidden_layer_sizes': 400, 'max_iter': 8000, 'solver': 'adam', 'tol': 0.0001}

# %%
best_grid = grid_search.best_estimator_

# %%
best_grid
# Out:
# MLPClassifier(hidden_layer_sizes=400, max_iter=8000, random_state=1)

# %%
ytrain_predict = best_grid.predict(x_train)
ytest_predict = best_grid.predict(x_test)

# %%
ytrain_predict1 = best_grid.predict_proba(x_train)
ytest_predict1 = best_grid.predict_proba(x_test)

# %%
sns.heatmap(confusion_matrix(y_train,ytrain_predict), annot = True, cmap = 'Spectral', fmt='4g')
# Out:
# <AxesSubplot:>

# %%
tn, fp, fn, tp  = confusion_matrix(y_train,ytrain_predict).ravel()
tn, fp, fn, tp
# Out:
# (1342, 129, 281, 348)

# %%
best_grid.score(x_train,train_labels)
# Out:
# 0.6033333333333334

# %%
(1362+252)/(1362+109+377+252)
# Out:
# 0.7685714285714286

# %%
print(classification_report(y_train,ytrain_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1471
#            1       0.73      0.55      0.63       629
#
#     accuracy                           0.80      2100
#    macro avg       0.78      0.73      0.75      2100
# weighted avg       0.80      0.80      0.80      2100

# %%
# keep probabilities for the positive outcome only
ytrain_predict1 = ytrain_predict1[:,1]

# calculate roc curve
fpr, tpr, thresholds = roc_curve(train_labels, ytrain_predict1)
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(fpr, tpr, marker='x')

# show the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()

# calculate AUC
auc = roc_auc_score(train_labels, ytrain_predict1)
print('Area under Curve is AUC: %.2f' % auc)
# Out:
# Area under Curve is AUC: 0.50

# %%
#  Similarily for test data

# %%
confusion_matrix(test_labels,ytest_predict)
# Out:
# array([[520, 126],
#        [200,  54]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(test_labels,ytest_predict), annot = True, cmap = 'Spectral', fmt='4g')
# Out:
# <AxesSubplot:>

# %%
best_grid.score(x_test,test_labels)
# Out:
# 0.6377777777777778

# %%
(543+35)/(543+96+226+35)
# Out:
# 0.6422222222222222

# %%
print(classification_report(test_labels,ytest_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.80      0.76       646
#            1       0.30      0.21      0.25       254
#
#     accuracy                           0.64       900
#    macro avg       0.51      0.51      0.51       900
# weighted avg       0.60      0.64      0.62       900

# %%
# keep probabilities for the positive outcome only
ytest_predict1 = ytest_predict1[:,1]

# calculate roc curve
fpr, tpr, thresholds = roc_curve(test_labels, ytest_predict1)
plt.plot([0, 1], [0, 1], linestyle='--')

# plot the roc curve for the model
plt.plot(fpr, tpr, marker='x')

# show the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.show()

# calculate AUC
auc = roc_auc_score(test_labels, ytest_predict1)
print('Area under Curve is AUC: %.2f' % auc)
# Out:
# Area under Curve is AUC: 0.50
